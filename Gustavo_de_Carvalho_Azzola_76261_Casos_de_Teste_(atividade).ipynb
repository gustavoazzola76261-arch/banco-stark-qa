# %% [markdown]
# Caso de teste

# %%
Template — Caso de Teste 1
ID: CT-001
Título/Objetivo: Criar conta
Pré-condição: Não ter uma conta

Passos:
1. Rodar o sistema
2. Criar conta

Resultado esperado: Conta criada para " Pessoa "
Resultado obtido: Conta criada para Pantera negra
Status (Pass/Fail): Pass
Evidência: Conta criada para Pantera negra

# %%
Template — Caso de Teste 2
ID: CT-002
Título/Objetivo: Depositar dinheiro
Pré-condição: Ter uma conta
Passos:
1. Rodar o sistema
2. TER uma conta
3. Depositar dinheiro

Resultado esperado: Depósito realizado: "Valor"
Resultado obtido: Depósito realizado: 500000
Status (Pass/Fail): Pass
Evidência: Depósito realizado: 500000

# %%
Template — Caso de Teste 3
ID: CT-003
Título/Objetivo: Sacar dinheiro
Pré-condição: Ter uma conta
Passos:
1. Rodar o sistema
2. Ter uma conta
3. Sacar dinheiro

Resultado esperado: Saque realizado: "Valor"
Resultado obtido: Saque realizado: 15000
Status (Pass/Fail): Pass
Evidência: Saque realizado: 15000

# %% [markdown]
# Bugs

# %%
Título: Tranferir =-10000

Severidade (Baixa/Média/Alta): Alta
Prioridade (Baixa/Média/Alta): Alta

Ambiente: Google Colab / Python 3.x / Banco do Stark

Descrição: Usuario consegue fazer uma tranferencia com valor negativo

Passos para reproduzir:
1. banco rodando
2. Escolha duas contas existentes para fazer a tranferencia
3. coloque um valor negativo para fazer a tranferencia

Resultado esperado: Valor invalido para tranferencia
Resultado obtido: OK - Transferência realizada: -10000
Evidência: OK - Transferência realizada: -10000
Impacto/Risco:
Impacto:
Alto impacto, pois permite alteração incorreta de saldos e compromete a integridade das transações financeiras do sistema.

Risco:
Alto risco de prejuízos financeiros, fraudes e inconsistências contábeis caso a falha seja explorada em produção.

# %%
Título: Permite saque com valor negativo (-15000)

Severidade (Baixa/Média/Alta): Alta
Prioridade (Baixa/Média/Alta): Alta

Ambiente: Google Colab / Python 3.x / Banco do Stark

Descrição: O sistema permite realizar uma operação de saque utilizando um valor negativo (-15000). Essa operação não deveria ser permitida, pois viola as regras básicas de transações financeiras.

Passos para reproduzir:
1. Acessar o sistema Banco.
2. Acessar a funcionalidade de saque.
3. Inserir o valor -15000 no campo de valor.
4. Confirmar a operação.

Resultado esperado:
O sistema deve bloquear a operação e exibir uma mensagem informando que apenas valores positivos são permitidos para saque.

Resultado obtido:
O sistema aceita o valor negativo e processa a operação de saque.

Evidência: Saque realizado: -15000

Impacto/Risco:
Alto impacto e risco, pois pode gerar inconsistências no saldo das contas e possibilitar exploração da falha para manipulação financeira.

# %%
Título: Permite transferência com valor igual a 0

Severidade (Baixa/Média/Alta): Média
Prioridade (Baixa/Média/Alta): Média

Ambiente: Google Colab / Python 3.x / Banco do Stark

Descrição: O sistema permite realizar uma transferência entre contas com valor igual a 0, o que não representa uma transação financeira válida e não deveria ser permitido pelas regras de negócio.

Passos para reproduzir:

1. Acessar o sistema Banco.
2. Acessar a funcionalidade de transferência.
3. Inserir uma conta de destino válida.
4. Informar o valor 0 no campo de valor da transferência.
5. Confirmar a operação.

Resultado esperado: O sistema deve bloquear a operação e informar que o valor da transferência deve ser maior que zero.

Resultado obtido: O sistema aceita o valor 0 e processa a transferência.

Evidência: OK - Transferência realizada: 0
Impacto/Risco: Impacto médio, pois pode gerar registros desnecessários de transações no sistema, causar inconsistências em relatórios financeiros e indicar falta de validação nas regras de negócio.
